# %% [markdown]
# # Ex 1:
# Given a undirected graph with edges = [(1, 2), (1, 6), (2, 3), (2, 4), (2, 6),
#          (3, 4), (3, 5), (4, 8), (4, 9), (6, 7)]
#
# 1. Draw the graph
# 2. Print the total number of nodes
# 3. Print the Total number of edges
# 4. List of all edges
# 5. Find degree of a given

# %%
import networkx as nx
import networkx
import numpy as np
import matplotlib.pyplot as plt

G = nx.Graph()
G.add_edges_from([(1, 2), (1, 6), (2, 3), (2, 4), (2, 6), (3, 4), (3, 5), (4, 8), (4, 9), (6, 7)])

nx.draw_networkx(G, with_labels=True)

print("Total number of nodes: ", int(G.number_of_nodes()))
print("Total number of edges: ", int(G.number_of_edges()))
print("List of all nodes: ", list(G.nodes()))
print("List of all edges: ", list(G.edges()))

G.degree[1]
# Out:
# Total number of nodes:  9
# Total number of edges:  10
# List of all nodes:  [1, 2, 6, 3, 4, 5, 8, 9, 7]
# List of all edges:  [(1, 2), (1, 6), (2, 3), (2, 4), (2, 6), (6, 7), (3, 4), (3, 5), (4, 8), (4, 9)]
# 2

# %% [markdown]
# # Ex 2: Using NetworkX, read file practice.txt
#
# In the practice.txt, the format of each row: node - node - edge type.
#
# Question:
# 1. Draw the graph.
#
# 2. Print:
#     - The total number of nodes, edges,
#     - List of nod
#
# 2. Print all the neighbours of node E.
#
# 3. Print all the neighbours of node E who are its friends.

# %%
import networkx as nx
import networkx
import numpy as np
import matplotlib.pyplot as plt


G=nx.MultiGraph()
G = nx.read_edgelist('practice1.txt', data =[('relation', str)])

nx.draw_networkx(G, with_labels=True)

# %%
#print("Total number of nodes: ", int(G.number_of_nodes()))
#print("Total number of edges: ", int(G.number_of_edges()))
#print("List of all nodes: ", list(G.nodes()))
#print("List of all edges: ", list(G.edges(data = True)))
print("List of all nodes we can go to in a single step from node E: ", list(G.neighbors('E')))
for i in list(G.neighbors('E')):
    if(G[i]['E']["relation"]=='friend'):
        print(i)
# Out:
# List of all nodes we can go to in a single step from node E:  ['C', 'D', 'I', 'J', 'H']
# C
# J

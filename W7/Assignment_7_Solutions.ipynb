# %% [markdown]
# ### Assignment 1. Write a python function:
#
# Input: graph G1, G2
#
# Output: return True, if G2 is a subgraph of G1
#
#         return False, otherwise

# %%
# g1 is the subgraph
# g2 is the full graph
def test_subgraph(g1, g2):
    #g1 = nx.Graph()
    #g2 = nx.Graph()
    #g1.add_edges_from(self.g1edges)
    #g2.add_edges_from(self.g2edges)
    #g3 = g2.subgraph([1,2,3,4])
    gm = iso.GraphMatcher(g1,g2)
    astert_true(gm.subgraph_is_isomorphic())

# %% [markdown]
# ### Assignment 2. Given two graphs,
#
# Print all Frequent Subgraph using gSpan method (with min_support = 2) and (the number of nodes in sugraph >=3)

# %% [markdown]
# ![pic.png](attachment:pic.png)

# %%
# !pip install gspan-mining
from gspan_mining.config import parser
from gspan_mining.main import main

# %% [markdown]
# #### With min_support = 2 and the number of nodes in sugraph >=3, we have:

# %%
args_str = '-s 2 -l 3 -p True ./graphdata/graphdata'
FLAGS, _ = parser.parse_known_args(args=args_str.split())

# %%
gs = main(FLAGS)
print(gs)
# Out:
# t # 0
# v 0 A
# v 1 C
# v 2 A
# e 0 1 1
# e 1 2 1
#
# Support: 2
# C:\Users\user\anaconda3\envs\test\lib\site-packages\gspan_mining\gspan.py:336: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._report_df = self._report_df.append(
# -----------------
#
# t # 1
# v 0 A
# v 1 C
# v 2 A
# v 3 B
# e 0 1 1
# e 1 2 1
# e 1 3 1
#
# Support: 2
# C:\Users\user\anaconda3\envs\test\lib\site-packages\gspan_mining\gspan.py:336: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._report_df = self._report_df.append(
# -----------------
#
# t # 2
# v 0 A
# v 1 C
# v 2 B
# e 0 1 1
# e 1 2 1
#
# Support: 2
# C:\Users\user\anaconda3\envs\test\lib\site-packages\gspan_mining\gspan.py:336: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

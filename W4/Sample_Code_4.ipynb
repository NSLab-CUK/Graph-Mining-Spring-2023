# %% [markdown]
# # Sample code of adjacency matrix and adjacency list in graph with networkx
# ## Install the necessary python libraries

# %%
# !pip install networkx pandas numpy matplotlib 
import networkx as nx
import numpy as np
# Out:
# Requirement already satisfied: networkx in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (3.0)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (1.5.3)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (1.24.2)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (from matplotlib) (4.39.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\graphmining\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# ### Spring layout

# %%
# Instantiate the graph
G = nx.Graph()

edges = [(0, 1, 2.1), (0, 2, 1.5), (0, 3, 2), (0, 5, 10), (1, 3, 1.6), (1, 6, 1.4), 
         (2, 3, 4), (3, 4, 2.5), (4, 5, 1.8), (4, 7, 2.3), (5, 8, 1.5), (8, 9, 1.9)]
# add node/edge pairs
G.add_weighted_edges_from(edges)

pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels = True)

labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
# Out:
# {(0, 1): Text(-0.1794805449733382, 0.0765963027482521, '2.1'),
#  (0, 2): Text(0.07733081558087095, -0.18148015039762902, '1.5'),
#  (0, 3): Text(-0.043627145296322375, -0.1099576633981934, '2'),
#  (0, 5): Text(0.09846848623228097, 0.025308403163981235, '10'),
#  (1, 3): Text(-0.23089116995374503, -0.04199252463619123, '1.6'),
#  (1, 6): Text(-0.5628279007261132, 0.29120001573014437, '1.4'),
#  (2, 3): Text(0.025920190600464105, -0.3000689777820723, '4'),
#  (3, 4): Text(-0.17239037043068997, -0.3107847703867826, '2.5'),
#  (5, 4): Text(-0.03029473890208663, -0.17551870382460796, '1.8'),
#  (5, 8): Text(0.42919942235871633, 0.2217421487526364, '1.5'),
#  (4, 7): Text(-0.39618345207510974, -0.5415369336514766, '2.3'),
#  (8, 9): Text(0.8346226759684776, 0.5250974925394234, '1.9')}

# %% [markdown]
# ## Directed graph

# %%
# Instantiate the graph
G = nx.DiGraph()

edges = [(0, 1, 2.1), (0, 2, 1.5), (0, 3, 2), (0, 5, 10), (1, 3, 1.6), (1, 6, 1.4), 
         (2, 3, 4), (3, 4, 2.5), (4, 5, 1.8), (4, 7, 2.3), (5, 8, 1.5), (8, 9, 1.9)]
# add node/edge pairs
G.add_weighted_edges_from(edges)

pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels = True)

labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
# Out:
# {(0, 1): Text(-0.2618264046866104, 0.19964764284222197, '2.1'),
#  (0, 2): Text(-0.02317861111886972, 0.021283148005103142, '1.5'),
#  (0, 3): Text(0.03780328816174648, -0.01794810524032514, '2'),
#  (0, 5): Text(-0.1835811782822142, -0.3048414329497076, '10'),
#  (1, 3): Text(-0.06573427489024371, 0.3068229661410917, '1.6'),
#  (1, 6): Text(-0.6826819838693003, 0.7510709919997995, '1.4'),
#  (2, 3): Text(0.17291351867749696, 0.12845847130397292, '4'),
#  (3, 4): Text(0.2761100650162479, 0.04547409985171106, '2.5'),
#  (5, 8): Text(-0.0734353124552816, -0.5847962019487365, '1.5'),
#  (4, 5): Text(0.054725598572287246, -0.24141922785767142, '1.8'),
#  (4, 7): Text(0.5380514528276321, 0.22742367505749975, '2.3'),
#  (8, 9): Text(0.15529819064638578, -0.8021117054115645, '1.9')}

# %% [markdown]
# ## Circular layout

# %%
# Instantiate the graph
G = nx.Graph()

edges = [(0, 1, 2.1), (0, 2, 1.5), (0, 3, 2), (0, 5, 10), (1, 3, 1.6), (1, 6, 1.4), 
         (2, 3, 4), (3, 4, 2.5), (4, 5, 1.8), (4, 7, 2.3), (5, 8, 1.5), (8, 9, 1.9)]
# add node/edge pairs
G.add_weighted_edges_from(edges)

pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels = True)

labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
# Out:
# {(0, 1): Text(0.9045085018604486, 0.29389263494502404, '2.1'),
#  (0, 2): Text(0.6545084884494037, 0.4755282818745524, '1.5'),
#  (0, 3): Text(0.3454914877087385, 0.4755282520722302, '2'),
#  (0, 5): Text(0.09549150410001578, 0.29389263494502404, '10'),
#  (1, 3): Text(0.24999998956918715, 0.7694208723145122, '1.6'),
#  (1, 6): Text(-0.09549149217908687, 0.29389259123363604, '1.4'),
#  (2, 3): Text(-2.3841857793582832e-08, 0.9510565192440406, '4'),
#  (3, 4): Text(-0.5590169783889235, 0.18163560202762602, '2.5'),
#  (5, 4): Text(-0.8090169619976462, -1.5099580141786362e-08, '1.8'),
#  (5, 8): Text(-0.24999993294477502, -0.18163560242446414, '1.5'),
#  (4, 7): Text(-0.5590170230924068, -0.7694208727113503, '2.3'),
#  (8, 9): Text(0.5590170350133357, -0.7694208727113503, '1.9')}

# %% [markdown]
# ## Circular layout in directed graph

# %%
# Instantiate the graph
G = nx.DiGraph()

edges = [(0, 1, 2.1), (0, 2, 1.5), (0, 3, 2), (0, 5, 10), (1, 3, 1.6), (1, 6, 1.4), 
         (2, 3, 4), (3, 4, 2.5), (4, 5, 1.8), (4, 7, 2.3), (5, 8, 1.5), (8, 9, 1.9)]
# add node/edge pairs
G.add_weighted_edges_from(edges)

pos = nx.circular_layout(G)
nx.draw(G, pos, with_labels = True)

labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
# Out:
# {(0, 1): Text(0.9045085018604486, 0.29389263494502404, '2.1'),
#  (0, 2): Text(0.6545084884494037, 0.4755282818745524, '1.5'),
#  (0, 3): Text(0.3454914877087385, 0.4755282520722302, '2'),
#  (0, 5): Text(0.09549150410001578, 0.29389263494502404, '10'),
#  (1, 3): Text(0.24999998956918715, 0.7694208723145122, '1.6'),
#  (1, 6): Text(-0.09549149217908687, 0.29389259123363604, '1.4'),
#  (2, 3): Text(-2.3841857793582832e-08, 0.9510565192440406, '4'),
#  (3, 4): Text(-0.5590169783889235, 0.18163560202762602, '2.5'),
#  (5, 8): Text(-0.24999993294477502, -0.18163560242446414, '1.5'),
#  (4, 5): Text(-0.8090169619976462, -1.5099580141786362e-08, '1.8'),
#  (4, 7): Text(-0.5590170230924068, -0.7694208727113503, '2.3'),
#  (8, 9): Text(0.5590170350133357, -0.7694208727113503, '1.9')}
